# %%
import pandas as pd
import geopandas as gpd
import shapely
import numpy as np

import seaborn as sns
import matplotlib as mpl
from lonboard import Map, viz, SolidPolygonLayer, PathLayer

# %%
from typing import List


def create_grid(
    gdf: None,
    bounds: List[float] | None = None,
    n_cells=10,
    overlap=False,
    crs="EPSG:4326",
):
    """Create square grid that covers a geodataframe area
    or a fixed boundary with x-y coords
    returns: a GeoDataFrame of grid polygons
    see https://james-brennan.github.io/posts/fast_gridding_geopandas/
    """

    import geopandas as gpd
    import shapely

    if bounds != None:
        xmin, ymin, xmax, ymax = bounds
    else:
        xmin, ymin, xmax, ymax = gdf.total_bounds

    # get cell size
    cell_size = (xmax - xmin) / n_cells
    # create the cells in a loop
    grid_cells = []
    for x0 in np.arange(xmin, xmax + cell_size, cell_size):
        for y0 in np.arange(ymin, ymax + cell_size, cell_size):
            x1 = x0 - cell_size
            y1 = y0 + cell_size
            poly = shapely.geometry.box(x0, y0, x1, y1)
            # print (gdf.overlay(poly, how='intersection'))
            grid_cells.append(poly)

    cells = gpd.GeoDataFrame(grid_cells, columns=["geometry"], crs=crs)
    if overlap == True:
        cols = ["grid_id", "geometry", "grid_area"]
        cells = cells.sjoin(gdf, how="inner").drop_duplicates("geometry")
    return cells


def create_hex_grid(gdf=None, bounds=None, n_cells=10, overlap=False, crs="EPSG:4326"):
    """Hexagonal grid over geometry.
    See https://sabrinadchan.github.io/data-blog/building-a-hexagonal-cartogram.html
    """

    from shapely.geometry import Polygon
    import geopandas as gpd

    if bounds != None:
        xmin, ymin, xmax, ymax = bounds
    else:
        xmin, ymin, xmax, ymax = gdf.total_bounds

    unit = (xmax - xmin) / n_cells
    a = np.sin(np.pi / 3)
    cols = np.arange(np.floor(xmin), np.ceil(xmax), 3 * unit)
    rows = np.arange(np.floor(ymin) / a, np.ceil(ymax) / a, unit)

    # print (len(cols))
    hexagons = []
    for x in cols:
        for i, y in enumerate(rows):
            if i % 2 == 0:
                x0 = x
            else:
                x0 = x + 1.5 * unit

            hexagons.append(
                Polygon(
                    [
                        (x0, y * a),
                        (x0 + unit, y * a),
                        (x0 + (1.5 * unit), (y + unit) * a),
                        (x0 + unit, (y + (2 * unit)) * a),
                        (x0, (y + (2 * unit)) * a),
                        (x0 - (0.5 * unit), (y + unit) * a),
                    ]
                )
            )

    grid = gpd.GeoDataFrame({"geometry": hexagons}, crs=crs)
    grid["grid_area"] = grid.area
    grid = grid.reset_index().rename(columns={"index": "grid_id"})
    if overlap == True:
        cols = ["grid_id", "geometry", "grid_area"]
        grid = grid.sjoin(gdf, how="inner").drop_duplicates("geometry")
    return grid

# %%
# Liens data.montpellier3m.fr
poles_zonage_3m_url = "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_MMM_PolesZonage_0.zip"

# cadastre archive contains multiple shapefiles (hydro, bati...)
cadastre_3m_url = (
    "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_MMM_Cadastre.zip"
)
contour_3m_url = (
    "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_MMM_Contours.zip"
)
occsol_3m_url = (
    "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_MMM_OccupSol.zip"
)

# %%
hydro = gpd.read_file("./data/3m/MMM_MMM_Cadastre/hydro.shp", crs="EPSG:2154")
hydro_4326 = hydro.to_crs(4326)
hydro_4326.head()
# Out:
#   Codcomm          Nom  Shape_Leng  Shape_Area  \
# 0  340022  Cours d'eau  487.376664  1173.38270
# 1  340022  Cours d'eau  227.808713   231.65925
# 2  340022  Cours d'eau  471.711913   771.88485
# 3  340022  Cours d'eau  248.795001   247.59915
# 4  340022  Cours d'eau   65.798798    46.63380
#
#                                             geometry
# 0  POLYGON ((4.02933 43.66297, 4.02938 43.66286, ...
# 1  POLYGON ((4.02342 43.65939, 4.02343 43.65934, ...
# 2  POLYGON ((4.02705 43.66378, 4.02738 43.66370, ...
# 3  POLYGON ((4.02559 43.66473, 4.02561 43.66474, ...
# 4  POLYGON ((4.02663 43.66381, 4.02663 43.66383, ...

# %%
occsol = gpd.read_file(
    "./data/3m/MMM_MMM_OccupSol/MMM_MMM_OccupSol.shp", crs="EPSG:2154"
)
occsol["area_sqm"] = occsol["geometry"].area
occsol_4326 = occsol.to_crs(4326)
occsol_4326.head()

# %%
occsol = gpd.read_file(
    "./data/3m/MMM_MMM_Contours/MMM_MMM_Contours.shp", crs="EPSG:2154"
)
occsol["area_sqm"] = occsol["geometry"].area
occsol_4326 = occsol.to_crs(4326)
occsol_4326.head()
# Out:
#                                   nom  \
# 0  Montpellier Méditerranée Métropole
#
#                                             geometry      area_sqm
# 0  POLYGON ((3.93860 43.58388, 3.93873 43.58380, ...  4.390615e+08

# %%
occsol_4326 = occsol_4326[
    [
        "c2021_niv1",
        "lib21_niv1",
        "c2021_niv2",
        "lib21_niv2",
        "c2021_niv3",
        "lib21_niv3",
        "c2021_niv4",
        "lib21_niv4",
        "geometry",
        "area_sqm",
    ]
]
occsol_4326.head()
# Out:
#    c2021_niv1                   lib21_niv1  c2021_niv2  \
# 0           7  Espaces naturels non boisés          78
# 1           5            Espaces agricoles          51
# 2           5            Espaces agricoles          51
# 3           8                          Eau          82
# 4           5            Espaces agricoles          51
#
#                                           lib21_niv2  c2021_niv3  \
# 0                               Marais et tourbières         782
# 1  Terres arables non inondées et espaces prairia...         512
# 2  Terres arables non inondées et espaces prairia...         512
# 3                   Eaux continentales ou littorales         822
# 4  Terres arables non inondées et espaces prairia...         512
#
#                           lib21_niv3  c2021_niv4  \
# 0                   Marais maritimes        7820
# 1             Espaces libres urbains        5121
# 2             Espaces libres urbains        5121
# 3  Plans d'eau et lagunes littorales        8220
# 4             Espaces libres urbains        5121
#
#                           lib21_niv4  \
# 0                   Marais maritimes
# 1             Espaces libres urbains
# 2             Espaces libres urbains
# 3  Plans d'eau et lagunes littorales
# 4             Espaces libres urbains
#
#                                             geometry     area_sqm
# 0  POLYGON ((3.52091 43.33206, 3.52067 43.33208, ...    52.109847
# 1  POLYGON ((4.04166 43.72099, 4.04181 43.72099, ...    42.143768
# 2  POLYGON ((4.00635 43.65290, 4.00705 43.65311, ...   844.590079
# 3  POLYGON ((3.99209 43.58774, 3.99106 43.58706, ...  2974.821151
# 4  POLYGON ((3.72840 43.55274, 3.72856 43.55307, ...  1387.993852

# %%
layer = SolidPolygonLayer.from_geopandas(occsol_4326)
m = Map(layers=[layer])
m
# Out:
# Map(layers=[SolidPolygonLayer(table=pyarrow.Table
# c2021_niv1: uint8
# lib21_niv1: string
# c2021_niv2: uint8
# lib21…

# %%
from palettable.colorbrewer.sequential import Blues_8
from lonboard.colormap import apply_continuous_cmap

layer.get_fill_color = apply_continuous_cmap(occsol_4326["c2021_niv1"] / 7, Blues_8)

# %%
occsol_4326_niv1_area = occsol_4326.groupby(["c2021_niv1", "lib21_niv1"])[
    "area_sqm"
].sum()
occsol_4326_niv1_area.head()
# Out:
# c2021_niv1  lib21_niv1
# 1           Espaces urbanisés                                                             1.929791e+08
# 2           Surfaces industrielles ou commerciales et infrastructures de communication    7.168349e+07
# 3           Extraction de matériaux, décharges, chantiers                                 1.014704e+07
# 4           Espaces récréatifs                                                            2.494645e+07
# 5           Espaces agricoles                                                             4.771698e+08
# Name: area_sqm, dtype: float64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3, figsize=(14, 7))
axs = ax.flat
occsol_4326.plot(ec="gray", fc="none", figsize=(10, 10), ax=axs[0])
grid = create_grid(occsol_4326, n_cells=25, overlap=True, crs="EPSG:4326")
grid.plot(fc="none", ec="black", ax=axs[1])
hexgrid = create_hex_grid(occsol_4326, n_cells=30, overlap=True, crs="EPSG:4326")
hexgrid.plot(fc="none", ec="black", ax=axs[2])
axs[0].axis("off")
axs[1].axis("off")
axs[2].axis("off")
# Out:
# /var/folders/99/kj4r22n55cv1_0hkwlk2tcph0000gn/T/ipykernel_42314/4172846853.py:85: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid["grid_area"] = grid.area
# (3.626136143226106, 4.106310266135886, 43.43238219845678, 43.79624481355155)

# %%
fig, ax = plt.subplots(1, 3, figsize=(14, 7))
axs = ax.flat
occsol.plot(ec="gray", fc="none", figsize=(10, 10), ax=axs[0])
grid = create_grid(occsol, n_cells=250, overlap=True, crs="EPSG:2154")
grid.plot(fc="none", ec="black", ax=axs[1])
hexgrid = create_hex_grid(occsol, n_cells=300, overlap=True, crs="EPSG:2154")
hexgrid.plot(fc="none", ec="black", ax=axs[2])
axs[0].axis("off")
axs[1].axis("off")
axs[2].axis("off")
# Out:
# (751359.7709607523, 787778.8790913981, 6261715.771996897, 6298790.788065171)

# %%
grid["size"] = grid["geometry"].length / 4
grid.head()
# Out:
#                                               geometry  index_right  \
# 85   POLYGON ((752938.924 6274583.727, 752938.924 6...            0
# 341  POLYGON ((753070.480 6274583.727, 753070.480 6...            0
# 342  POLYGON ((753070.480 6274715.283, 753070.480 6...            0
# 343  POLYGON ((753070.480 6274846.839, 753070.480 6...            0
# 596  POLYGON ((753202.036 6274452.171, 753202.036 6...            0
#
#                                     nom      area_sqm       size
# 85   Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 341  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 342  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 343  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 596  Montpellier Méditerranée Métropole  4.390615e+08  131.55608

# %%
layer = SolidPolygonLayer.from_geopandas(occsol_4326)
grid = SolidPolygonLayer.from_geopandas(grid)
m = Map(layers=[layer, grid])
m
# Out:
# /Users/gaetan/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/lonboard/_layer.py:133: UserWarning: GeoDataFrame being reprojected to EPSG:4326
#   warnings.warn("GeoDataFrame being reprojected to EPSG:4326")
# Map(layers=[SolidPolygonLayer(table=pyarrow.Table
# nom: string
# area_sqm: double
# geometry: list<item: list<item:…

# %%
from palettable.colorbrewer.sequential import Blues_8
from lonboard.colormap import apply_continuous_cmap

layer.get_fill_color = apply_continuous_cmap(occsol_4326["c2021_niv1"] / 7, Blues_8)
grid.get_fill_color = [13, 124, 56, 12]
grid.extruded = True
grid.wireframe = True
grid.get_elevation = 25
grid.get_line_color = [0, 0, 0, 255]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c2021_niv1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 4
#       1 from palettable.colorbrewer.sequential import Blues_8
#       2 from lonboard.colormap import apply_continuous_cmap
# ----> 4 layer.get_fill_color = apply_continuous_cmap(occsol_4326["c2021_niv1"] / 7, Blues_8)
#       5 grid.get_fill_color = [13, 124, 56, 12]
#       6 grid.extruded = True
#
# File ~/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/geopandas/geodataframe.py:1474, in GeoDataFrame.__getitem__(self, key)
#    1468 def __getitem__(self, key):
#    1469     """
#    1470     If the result is a column containing only 'geometry', return a
#    1471     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1472     return a GeoDataFrame.
#    1473     """
# -> 1474     result = super().__getitem__(key)
#    1475     # Custom logic to avoid waiting for pandas GH51895
#    1476     # result is not geometry dtype for multi-indexes
#    1477     if (
#    1478         pd.api.types.is_scalar(key)
#    1479         and key == ""
#    (...)
#    1482         and not is_geometry_type(result)
#    1483     ):
#
# File ~/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'c2021_niv1'

# %%
grid.plot()
# Out:
# <Axes: >

# %%
grid.head()
# Out:
#                                               geometry  index_right  \
# 85   POLYGON ((752938.924 6274583.727, 752938.924 6...            0
# 341  POLYGON ((753070.480 6274583.727, 753070.480 6...            0
# 342  POLYGON ((753070.480 6274715.283, 753070.480 6...            0
# 343  POLYGON ((753070.480 6274846.839, 753070.480 6...            0
# 596  POLYGON ((753202.036 6274452.171, 753202.036 6...            0
#
#                                     nom      area_sqm       size
# 85   Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 341  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 342  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 343  Montpellier Méditerranée Métropole  4.390615e+08  131.55608
# 596  Montpellier Méditerranée Métropole  4.390615e+08  131.55608

# %%
grid_item = grid.loc[[596], "geometry"]
grid_item.plot()
# Out:
# <Axes: >

# %%
import time
from urllib.parse import urlparse, parse_qs
import requests
import xarray as xr


def formatBBox(bounds):
    xmin, ymin, xmax, ymax = bounds
    return f"{xmin},{ymin},{xmax},{ymax}"


def getTileUrl(
    layerName="ORTHOIMAGERY.ORTHOPHOTOS.IRC",
    bbox="785802.3085941937752,6336806.404346071184,786208.1537742479704,6337311.468582574278",
    size=256,
):
    base_url = "https://wxs.ign.fr/ortho/geoportail/r/wms"
    params = f"SERVICE=WMS&VERSION=1.3.0&REQUEST=GetMap&BBOX={bbox}&CRS=EPSG:2154&WIDTH={size}&HEIGHT={size}&LAYERS={layerName}&STYLES=&FORMAT=image/geotiff&DPI=72&MAP_RESOLUTION=72&FORMAT_OPTIONS=dpi:72"
    return f"{base_url}?{params}"


def download_image_from_url(url=""):
    t0 = time.time()
    parsed_url = urlparse(url)
    layer_param = parse_qs(parsed_url.query)["LAYERS"][0]
    bbox_param = parse_qs(parsed_url.query)["BBOX"][0]
    bbox_tuple = tuple(map(float, bbox_param.split(",")))
    if layer_param == "ORTHOIMAGERY.ORTHOPHOTOS.IRC":
        out_dir = "./tiles/irc"
    elif layer_param == "ORTHOIMAGERY.ORTHOPHOTOS.BDORTHO":
        out_dir = "./downloads/tiles/ortho"
    else:
        out_dir = "./downloads/tiles/unknown"
    try:
        r = requests.get(url)
        print(r.status_code)
        if r.status_code == 200:
            image_path = f"{out_dir}/image_{hash(bbox_tuple)}.tiff"
            with open(image_path, "wb") as f:
                f.write(r.content)
        return (image_path, time.time() - t0, url)
    except Exception as e:
        print("Exception in download_url():", e)

# %%
url = getTileUrl(
    layerName="ORTHOIMAGERY.ORTHOPHOTOS.BDORTHO",
    bbox=formatBBox(grid_item.total_bounds),
)
url
# Out:
# 'https://wxs.ign.fr/ortho/geoportail/r/wms?SERVICE=WMS&VERSION=1.3.0&REQUEST=GetMap&BBOX=753202.0360484155,6274452.17075707,753333.5921283576,6274583.726837012&CRS=EPSG:2154&WIDTH=256&HEIGHT=256&LAYERS=ORTHOIMAGERY.ORTHOPHOTOS.BDORTHO&STYLES=&FORMAT=image/geotiff&DPI=72&MAP_RESOLUTION=72&FORMAT_OPTIONS=dpi:72'

# %%
d = download_image_from_url(url)
# Out:
# 200

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt

fp = r"GeoTiff_Image.tif"
img = rasterio.open(d[0])
show(img.read(3))
# plt.imshow(img.read(3))
# Out:
# <Axes: >

# %%
occsol.head()
# Out:
#    c1994_niv1                                         lib94_niv1  c1994_niv2  \
# 0           7                        Espaces naturels non boisés          78
# 1           5                                  Espaces agricoles          52
# 2           2  Surfaces industrielles ou commerciales et infr...          22
# 3           8                                                Eau          82
# 4           5                                  Espaces agricoles          52
#
#                                   lib94_niv2  c2004_niv1  \
# 0                       Marais et tourbières           7
# 1                       Cultures permanentes           5
# 2  Infrastructures routières et ferroviaires           2
# 3           Eaux continentales ou littorales           8
# 4                       Cultures permanentes           5
#
#                                           lib04_niv1  c2004_niv2  \
# 0                        Espaces naturels non boisés          78
# 1                                  Espaces agricoles          52
# 2  Surfaces industrielles ou commerciales et infr...          22
# 3                                                Eau          82
# 4                                  Espaces agricoles          52
#
#                                   lib04_niv2  c2004_niv3  \
# 0                       Marais et tourbières         782
# 1                       Cultures permanentes         521
# 2  Infrastructures routières et ferroviaires         222
# 3           Eaux continentales ou littorales         822
# 4                       Cultures permanentes         521
#
#                                lib04_niv3  ...     milieu2004     milieu2008  \
# 0                        Marais maritimes  ...        NATUREL        NATUREL
# 1                                  Vignes  ...       AGRICOLE       AGRICOLE
# 2  Réseau ferroviaire et espaces associés  ...  ARTIFICIALISE  ARTIFICIALISE
# 3       Plans d'eau et lagunes littorales  ...        NATUREL        NATUREL
# 4                                  Vignes  ...       AGRICOLE       AGRICOLE
#
#       milieu2010     milieu2012     milieu2015     milieu2017     milieu2019  \
# 0        NATUREL        NATUREL        NATUREL        NATUREL        NATUREL
# 1       AGRICOLE       AGRICOLE       AGRICOLE       AGRICOLE  ARTIFICIALISE
# 2  ARTIFICIALISE  ARTIFICIALISE  ARTIFICIALISE  ARTIFICIALISE        NATUREL
# 3        NATUREL        NATUREL        NATUREL        NATUREL        NATUREL
# 4  ARTIFICIALISE        NATUREL        NATUREL  ARTIFICIALISE        NATUREL
#
#   milieu2021                                           geometry     area_sqm
# 0    NATUREL  POLYGON ((742269.535 6248240.552, 742250.300 6...    52.109847
# 1    NATUREL  POLYGON ((783953.823 6291883.226, 783966.394 6...    42.143768
# 2    NATUREL  POLYGON ((781205.235 6284279.038, 781260.980 6...   844.590079
# 3    NATUREL  POLYGON ((780145.613 6277024.020, 780063.022 6...  2974.821151
# 4    NATUREL  POLYGON ((758879.856 6272901.789, 758892.140 6...  1387.993852
#
# [5 rows x 71 columns]

# %%
from shapely.geometry import box

# polygon = box(grid_item.total_bounds[0], grid_item.total_bounds[1], grid_item.total_bounds[2], grid_item.total_bounds[3])

# extent = gpd.GeoDataFrame([1], geometry=[polygon], crs=4326)
clipped = gpd.clip(occsol, grid_item.total_bounds)
clipped.head()
# Out:
# Empty GeoDataFrame
# Columns: [c1994_niv1, lib94_niv1, c1994_niv2, lib94_niv2, c2004_niv1, lib04_niv1, c2004_niv2, lib04_niv2, c2004_niv3, lib04_niv3, c2008_niv1, lib08_niv1, c2008_niv2, lib08_niv2, c2008_niv3, lib08_niv3, c2010_niv1, lib10_niv1, c2010_niv2, lib10_niv2, c2010_niv3, lib10_niv3, c2012_niv1, lib12_niv1, c2012_niv2, lib12_niv2, c2012_niv3, lib12_niv3, c2015_niv1, lib15_niv1, c2015_niv2, lib15_niv2, c2015_niv3, lib15_niv3, c2015_niv4, lib15_niv4, c2017_niv1, lib17_niv1, c2017_niv2, lib17_niv2, c2017_niv3, lib17_niv3, c2017_niv4, lib17_niv4, c2019_niv1, lib19_niv1, c2019_niv2, lib19_niv2, c2019_niv3, lib19_niv3, c2019_niv4, lib19_niv4, c2021_niv1, lib21_niv1, c2021_niv2, lib21_niv2, c2021_niv3, lib21_niv3, c2021_niv4, lib21_niv4, milieu1994, milieu2004, milieu2008, milieu2010, milieu2012, milieu2015, milieu2017, milieu2019, milieu2021, geometry, area_sqm]
# Index: []
#
# [0 rows x 71 columns]

# %%
grid_item.total_bounds
# Out:
# array([ 739754.26719998, 6250348.78720265,  739979.89999998,
#        6250574.42000265])

# %%
hydro = gpd.read_file("./data/3m/MMM_MMM_Cadastre/hydro.shp", crs="EPSG:2154")
clipped = gpd.clip(hydro, grid_item.total_bounds)
clipped.head()
# Out:
# Empty GeoDataFrame
# Columns: [Codcomm, Nom, Shape_Leng, Shape_Area, geometry]
# Index: []

# %%
boundaries = gpd.read_file(
    "./data/3m/MMM_MMM_PolesZonage/MMM_MMM_PolesZonage.shp", crs="EPSG:2154"
)
castries = boundaries[boundaries["nom"] == "CASTRIES"]
castries.plot()
castries_hydro
# Out:
# <Axes: >

# %%
castries_hydro = hydro.clip(castries)
castries_hydro.plot()
# Out:
# <Axes: >

# %%
grid.head()
grid_light = grid[["geometry", "area_sqm", "size"]]
grid_light.reset_index()
grid_light.insert(1, "id", range(1, 1 + len(grid_light)))
grid_light.head()
# Out:
#                                               geometry  id      area_sqm  \
# 24   POLYGON ((739754.267 6250348.787, 739754.267 6...   1  89599.458945
# 279  POLYGON ((739979.900 6250348.787, 739979.900 6...   2  89599.458945
# 280  POLYGON ((739979.900 6250574.420, 739979.900 6...   3  89599.458945
# 534  POLYGON ((740205.533 6250348.787, 740205.533 6...   4  89599.458945
# 535  POLYGON ((740205.533 6250574.420, 740205.533 6...   5  89599.458945
#
#          size
# 24   225.6328
# 279  225.6328
# 280  225.6328
# 534  225.6328
# 535  225.6328

# %%
gitem = grid_light[grid_light["id"] == 17267]
gitem.plot()
# Out:
# <Axes: >

# %%
gitem_hydro = hydro.clip(gitem)
gitem_hydro.head()
# Out:
# Empty GeoDataFrame
# Columns: [Codcomm, Nom, Shape_Leng, Shape_Area, geometry]
# Index: []

# %%
gitem_boundaries = boundaries.clip(gitem)
gitem_boundaries.plot()
# Out:
# <Axes: >

# %%
occsol_4326.head()
# Out:
#    c2021_niv1                   lib21_niv1  c2021_niv2  \
# 0           7  Espaces naturels non boisés          78
# 1           5            Espaces agricoles          51
# 2           5            Espaces agricoles          51
# 3           8                          Eau          82
# 4           5            Espaces agricoles          51
#
#                                           lib21_niv2  c2021_niv3  \
# 0                               Marais et tourbières         782
# 1  Terres arables non inondées et espaces prairia...         512
# 2  Terres arables non inondées et espaces prairia...         512
# 3                   Eaux continentales ou littorales         822
# 4  Terres arables non inondées et espaces prairia...         512
#
#                           lib21_niv3  c2021_niv4  \
# 0                   Marais maritimes        7820
# 1             Espaces libres urbains        5121
# 2             Espaces libres urbains        5121
# 3  Plans d'eau et lagunes littorales        8220
# 4             Espaces libres urbains        5121
#
#                           lib21_niv4  \
# 0                   Marais maritimes
# 1             Espaces libres urbains
# 2             Espaces libres urbains
# 3  Plans d'eau et lagunes littorales
# 4             Espaces libres urbains
#
#                                             geometry     area_sqm
# 0  POLYGON ((3.52091 43.33206, 3.52067 43.33208, ...    52.109847
# 1  POLYGON ((4.04166 43.72099, 4.04181 43.72099, ...    42.143768
# 2  POLYGON ((4.00635 43.65290, 4.00705 43.65311, ...   844.590079
# 3  POLYGON ((3.99209 43.58774, 3.99106 43.58706, ...  2974.821151
# 4  POLYGON ((3.72840 43.55274, 3.72856 43.55307, ...  1387.993852

# %%
from lonboard import basemap

grid_light_4326 = grid_light.to_crs(4326)
hydro_4326 = hydro.to_crs(4326)
boundaries_4326 = boundaries.to_crs(4326)
grid_light_4326_layer = SolidPolygonLayer.from_geopandas(grid_light_4326)
hydro_4326_layer = SolidPolygonLayer.from_geopandas(hydro_4326)
boundaries_4326_layer = SolidPolygonLayer.from_geopandas(boundaries_4326)

# %%
landcover_4326_layer = SolidPolygonLayer.from_geopandas(occsol_4326)

# %%
grid_light_4326_layer.get_fill_color = [13, 124, 56]
grid_light_4326_layer.get_fill_color = [13, 124, 56]
grid_light_4326_layer.extruded = True
grid_light_4326_layer.wireframe = True
grid_light_4326_layer.opacity = 0.5
grid_light_4326_layer.get_elevation = 25
# grid_light_4326_layer.get_line_color = [0, 0, 0, 255]
boundaries_4326_layer.get_fill_color = [125, 12, 200]
boundaries_4326_layer.opacity = 0.3
landcover_4326_layer.get_fill_color = apply_continuous_cmap(
    landcover_4326_layer["c2021_niv1"] / 7, Blues_8
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gaetan/Code/projets/_NaturalSolutions/_Ecoteka/3m-ai/01-data-preparation/notebooks/3m-landcover-ai-data-preparation.ipynb Cell 35 line 1
#       <a href='vscode-notebook-cell:/Users/gaetan/Code/projets/_NaturalSolutions/_Ecoteka/3m-ai/01-data-preparation/notebooks/3m-landcover-ai-data-preparation.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a> boundaries_4326_layer.get_fill_color = [125, 12, 200]
#       <a href='vscode-notebook-cell:/Users/gaetan/Code/projets/_NaturalSolutions/_Ecoteka/3m-ai/01-data-preparation/notebooks/3m-landcover-ai-data-preparation.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a> boundaries_4326_layer.opacity = 0.3
# ---> <a href='vscode-notebook-cell:/Users/gaetan/Code/projets/_NaturalSolutions/_Ecoteka/3m-ai/01-data-preparation/notebooks/3m-landcover-ai-data-preparation.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a> landcover_4326_layer.get_fill_color = apply_continuous_cmap(landcover_4326_layer["c2021_niv1"] / 7, Blues_8)
#
# TypeError: 'SolidPolygonLayer' object is not subscriptable

# %%
m2 = Map(
    layers=[
        hydro_4326_layer,
        boundaries_4326_layer,
        grid_light_4326_layer,
        landcover_4326_layer,
    ],
    basemap_style=basemap.CartoBasemap.DarkMatterNoLabels,
)
m2

# %%
m3 = Map(layers=[landcover_4326_layer, boundaries_4326_layer])
m3
# Out:
# Map(layers=[SolidPolygonLayer(table=pyarrow.Table
# c2021_niv1: uint8
# lib21_niv1: string
# c2021_niv2: uint8
# lib21…

# %%
clipped_lancover = occsol_4326.clip(boundaries_4326)
clipped_lancover
# Out:
#        c2021_niv1                                         lib21_niv1  \
# 33464           7                        Espaces naturels non boisés
# 55988           2  Surfaces industrielles ou commerciales et infr...
# 15595           7                        Espaces naturels non boisés
# 20628           7                        Espaces naturels non boisés
# 55365           6                                     Espaces boisés
#
#        c2021_niv2                                 lib21_niv2  c2021_niv3  \
# 33464          72                  Végétations sclérophylles         721
# 55988          22  Infrastructures routières et ferroviaires         221
# 15595          72                  Végétations sclérophylles         721
# 20628          72                  Végétations sclérophylles         721
# 55365          62                        Conifères dominants         620
#
#                                          lib21_niv3  c2021_niv4  \
# 33464                           Maquis et garrigues        7210
# 55988  Réseau routier principal et espaces associés        2211
# 15595                           Maquis et garrigues        7210
# 20628                           Maquis et garrigues        7210
# 55365                           Conifères dominants        6200
#
#                                          lib21_niv4  \
# 33464                           Maquis et garrigues
# 55988  Réseau routier principal et espaces associés
# 15595                           Maquis et garrigues
# 20628                           Maquis et garrigues
# 55365                           Conifères dominants
#
#                                                 geometry      area_sqm
# 33464  MULTIPOLYGON (((3.74897 43.49729, 3.74919 43.4...  3.865199e+06
# 55988  POLYGON ((3.77903 43.50602, 3.77901 43.50603, ...  1.099487e+05
# 15595  MULTIPOLYGON (((3.77322 43.50297, 3.77322 43.5...  1.454626e+06
# 20628  POLYGON ((3.76372 43.49765, 3.76372 43.49768, ...  2.987545e+03
# 55365  POLYGON ((3.76703 43.49954, 3.76698 43.49948, ...  1.714738e+04

# %%
clipped_lancover_layer = SolidPolygonLayer.from_geopandas(clipped_lancover)
_m4 = Map(layers=[clipped_lancover_layer, boundaries_4326_layer])
_m4
# Out:
# Map(layers=[SolidPolygonLayer(table=pyarrow.Table
# c2021_niv1: uint8
# lib21_niv1: string
# c2021_niv2: uint8
# lib21…

# %%
clipped_lancover_layer.get_fill_color = apply_continuous_cmap(
    clipped_lancover["c2021_niv1"] / 7, Blues_8
)

# %%
bounds = clipped_lancover.total_bounds

# %%
grid_light.to_crs(4326)[]
clipped_landovers = grid_light.to_crs(4326).clip()
# Out:
# 17998

# %%
grid_light_4326 = grid_light.to_crs(4326)
castries_4326 = boundaries_4326[boundaries_4326["nom"] == "CASTRIES"]
grids_in_castries = gpd.sjoin(grid_light_4326, castries_4326, op="within", how="inner")
grids_in_castries.head()
# Out:
# /Users/gaetan/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3490: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#                                                 geometry     id      area_sqm  \
# 41247  POLYGON ((3.94345 43.68924, 3.94348 43.69127, ...  21081  67518.055701
# 41001  POLYGON ((3.94095 43.70753, 3.94098 43.70957, ...  21085  91783.353471
# 41002  POLYGON ((3.94098 43.70957, 3.94102 43.71160, ...  21086  91783.353471
# 41255  POLYGON ((3.94372 43.70548, 3.94375 43.70751, ...  21087  91783.353471
# 41256  POLYGON ((3.94375 43.70751, 3.94378 43.70954, ...  21088  91783.353471
#
#            size  index_right codcomm       nom                POLE
# 41247  225.6328            3  340058  CASTRIES  Cadoule et Bérange
# 41001  225.6328            3  340058  CASTRIES  Cadoule et Bérange
# 41002  225.6328            3  340058  CASTRIES  Cadoule et Bérange
# 41255  225.6328            3  340058  CASTRIES  Cadoule et Bérange
# 41256  225.6328            3  340058  CASTRIES  Cadoule et Bérange

# %%
gitem = grids_in_castries[grids_in_castries["id"] == 21086]
lancover_castries_21086 = occsol_4326.clip(gitem)
len(lancover_castries_21086)
# Out:
# 6

# %%
lancover_castries_21086.head()
# Out:
#        c2021_niv1                                         lib21_niv1  \
# 7974            7                        Espaces naturels non boisés
# 44698           6                                     Espaces boisés
# 59554           3      Extraction de matériaux, décharges, chantiers
# 55956           2  Surfaces industrielles ou commerciales et infr...
# 2824            7                        Espaces naturels non boisés
#
#        c2021_niv2                                     lib21_niv2  c2021_niv3  \
# 7974           72                      Végétations sclérophylles         721
# 44698          61                             Feuillus dominants         613
# 59554          31  Extraction de matériaux, décharges, chantiers         311
# 55956          22      Infrastructures routières et ferroviaires         221
# 2824           72                      Végétations sclérophylles         721
#
#                                          lib21_niv3  c2021_niv4  \
# 7974                            Maquis et garrigues        7210
# 44698              Feuillus sclérophylles dominants        6130
# 59554                       Extraction de matériaux        3111
# 55956  Réseau routier principal et espaces associés        2211
# 2824                            Maquis et garrigues        7210
#
#                                          lib21_niv4  \
# 7974                            Maquis et garrigues
# 44698              Feuillus sclérophylles dominants
# 59554                       Extraction de matériaux
# 55956  Réseau routier principal et espaces associés
# 2824                            Maquis et garrigues
#
#                                                 geometry      area_sqm
# 7974   POLYGON ((3.94195 43.71154, 3.94231 43.71119, ...  90747.778578
# 44698  POLYGON ((3.94288 43.70956, 3.94310 43.70976, ...  91783.353471
# 59554  POLYGON ((3.94330 43.71136, 3.94330 43.71143, ...   3197.025068
# 55956  POLYGON ((3.94257 43.71006, 3.94312 43.71086, ...  25461.456275
# 2824   POLYGON ((3.94381 43.71118, 3.94375 43.71107, ...  44622.703321

# %%
lancover_castries_21086.plot(column="c2021_niv1")
# Out:
# <Axes: >

# %%
lancover_castries_21086["c2021_niv1"] = pd.to_numeric(
    lancover_castries_21086["c2021_niv1"], downcast="float"
)
lancover_castries_21086.dtypes
# Out:
# c2021_niv1     float32
# lib21_niv1      object
# c2021_niv2       int64
# lib21_niv2      object
# c2021_niv3       int64
# lib21_niv3      object
# c2021_niv4       int64
# lib21_niv4      object
# geometry      geometry
# area_sqm       float64
# dtype: object

# %%
from geocube.api.core import make_geocube

out_grid = make_geocube(
    vector_data=lancover_castries_21086,
    output_crs="epsg:4326",
    resolution=(-0.000005, 0.000005),
    measurements=["c2021_niv1"],
    fill=-9999,
)

# %%
out_grid
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 412, x: 568)
# Coordinates:
#   * y            (y) float64 43.71 43.71 43.71 43.71 ... 43.71 43.71 43.71 43.71
#   * x            (x) float64 3.941 3.941 3.941 3.941 ... 3.944 3.944 3.944 3.944
#     spatial_ref  int64 0
# Data variables:
#     c2021_niv1   (y, x) float32 -9.999e+03 -9.999e+03 ... -9.999e+03 -9.999e+03

# %%
out_grid.c2021_niv1.rio.to_raster("./masks/lancover_castries_21086.tif")

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

fig = plt.figure(figsize=(15, 13))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
lancover_castries_21086.plot(ax=ax, facecolor="None", edgecolor="r")
da_grib = xr.where(out_grid.c2021_niv1 < -1999.0, np.nan, out_grid.c2021_niv1)
da_grib.plot(ax=ax, add_colorbar=False)

ax.set_title("Rasterized with 0.05$^o$ Grids", fontsize=24)
